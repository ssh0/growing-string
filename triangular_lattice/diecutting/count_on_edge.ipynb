# %% [markdown]
# # クラスターの型抜きにおける領域外縁点の状態のカウント
#
# `dicutting`の結果をそのまま見てもおもしろいのだが，これをより詳しく解析するために，カッティング領域の外縁部分における点を，その内部，外部とのつながり方で状態を分類し，それぞれの状態にある点の個数をカウントする。

# %%
# %matplotlib notebook
from result_count_on_edge import Visualizer

# %%
visualizer = Visualizer([])

# %% [markdown]
# まずは，普通にカッティング領域内のサブクラスター数をプロットしてみる。
#
# `set_data_path`で指定されたパスのデータが用いられる。
#
# 後半のデータで得られているデータは，ある$L$に対して平均を取るときに，うまく

# %%
visualizer.result_S()
# Out:
# <img src="data:image/png;base64,...">

# %%
visualizer.result_n0()
# Out:
# <img src="data:image/png;base64,...">

# %%
visualizer.result_n1()
# Out:
# <img src="data:image/png;base64,...">

# %%
visualizer.result_n2()
# Out:
# <img src="data:image/png;base64,...">
